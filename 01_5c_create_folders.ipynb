# %% [markdown]
# ## load library

# %%
import pickle
import os 
import shutil
import pandas as pd
import re
import numpy as np

# %% [markdown]
# ## load data

# %%
datadir = "/Users/saskia/unibe19/master_thesis/TKI_project/data/"
ds_dir = os.path.join(datadir, 'dataset_PC_HN')
info = pickle.load(open(os.path.join(ds_dir, "info.pckl"), "rb"))
info
# Out:
# {0: {'exp': 'LM',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': '1_il1b_1_s1c1.tif'},
#  1: {'exp': 'LM',
#   'stim': 'TNF',
#   'stim_class': 3,
#   'stim_class_simple': 2,
#   'bn': '2_TNF_1_s1c1.tif'},
#  2: {'exp': 'LM',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': '3_IL1B_1_s1.tif'},
#  3: {'exp': 'LM',
#   'stim': 'NS',
#   'stim_class': 0,
#   'stim_class_simple': 0,
#   'bn': '4_NS_1_s1c1.tif'},
#  4: {'exp': 'LM',
#   'stim': 'NS',
#   'stim_class': 0,
#   'stim_class_simple': 0,
#   'bn': '5_NS_1_s1c1.tif'},
#  5: {'exp': 'LM',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': '6_IL1B_1_s1c1.tif'},
#  6: {'exp': 'SS',
#   'stim': 'IL-1b Low',
#   'stim_class': 2,
#   'stim_class_simple': 1,
#   'bn': 'FC2_Il1b_low_1_s1c1.tif'},
#  7: {'exp': 'SS',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': 'FC3_Il1b_high_1_s1c1.tif'},
#  8: {'exp': 'SS',
#   'stim': 'IL-1b Low',
#   'stim_class': 2,
#   'stim_class_simple': 1,
#   'bn': 'FC4_Il1b_low_1_s1c1.tif'},
#  9: {'exp': 'SS',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': 'FC1_Il1b_1_to_13_1_s1c1.tif'},
#  10: {'exp': 'SS',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': 'FC2_Il1b_1_to_4_1_s1c1.tif'},
#  11: {'exp': 'SS',
#   'stim': 'TNF',
#   'stim_class': 3,
#   'stim_class_simple': 2,
#   'bn': 'FC3_TNFa_1_to_8_1_s1c1.tif'},
#  12: {'exp': 'SS',
#   'stim': 'NS',
#   'stim_class': 0,
#   'stim_class_simple': 0,
#   'bn': 'FC4_NS_1_to_8_1_s1c1.tif'},
#  13: {'exp': 'SS',
#   'stim': 'TNF',
#   'stim_class': 3,
#   'stim_class_simple': 2,
#   'bn': 'FC5_TNFa_1_to_8_1_s1c1.tif'},
#  14: {'exp': 'SS',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': 'FC6_Il1b_1_to_8_1_s1c1.tif'},
#  15: {'exp': 'SS',
#   'stim': 'TNF',
#   'stim_class': 3,
#   'stim_class_simple': 2,
#   'bn': 'FC7_TNFa_1_to_8_1_s1c1.tif'},
#  16: {'exp': 'SS',
#   'stim': 'NS',
#   'stim_class': 0,
#   'stim_class_simple': 0,
#   'bn': 'FC8_NS_1_to_8_1_s1c1.tif'},
#  17: {'exp': 'SS',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': 'FC9_Il1b_1_to_8_1_s1c1.tif'},
#  18: {'exp': 'SS',
#   'stim': 'TNF',
#   'stim_class': 3,
#   'stim_class_simple': 2,
#   'bn': 'FC10_TNFa_1_to_8_1_s1c1.tif'},
#  19: {'exp': 'SS',
#   'stim': 'NS',
#   'stim_class': 0,
#   'stim_class_simple': 0,
#   'bn': 'FC11_NS_1_to_8_1_s1c1.tif'},
#  20: {'exp': 'SS',
#   'stim': 'IL-1b High',
#   'stim_class': 1,
#   'stim_class_simple': 1,
#   'bn': 'FC12_Il1b_1_to_8_1_s1c1.tif'},
#  21: {'exp': 'SS',
#   'stim': 'TNF',
#   'stim_class': 3,
#   'stim_class_simple': 2,
#   'bn': 'FC13_TNFa_1_to_8_1_s1c1.tif'},
#  22: {'exp': 'SS',
#   'stim': 'NS',
#   'stim_class': 0,
#   'stim_class_simple': 0,
#   'bn': 'FC14_NS_1_to_8_1_s1c1.tif'},
#  23: {'exp': 'SS',
#   'stim': 'TNF',
#   'stim_class': 3,
#   'stim_class_simple': 2,
#   'bn': 'FC15_TNFa_1_to_8_1_s1c1.tif'},
#  24: {'exp': 'SA',
#   'stim': 'TNF+IFN',
#   'stim_class': 4,
#   'stim_class_simple': 2,
#   'bn': '210217_EXP1_TNFIFN_tdTomOTI_1_h5s1c1.tif'},
#  25: {'exp': 'SA',
#   'stim': 'NS',
#   'stim_class': 0,
#   'stim_class_simple': 0,
#   'bn': '210217_EXP2_NS_tdTomOTI_1_s1c1.tif'},
#  26: {'exp': 'SA',
#   'stim': 'NS',
#   'stim_class': 0,
#   'stim_class_simple': 0,
#   'bn': '210217_EXP3_NS_tdTomOTI_1_s1c1.tif'},
#  27: {'exp': 'SA',
#   'stim': 'TNF+IFN',
#   'stim_class': 4,
#   'stim_class_simple': 2,
#   'bn': '210217_EXP4_TNFIFN_tdTomOTI_1_s1c1.tif'},
#  28: {'exp': 'SA',
#   'stim': 'TNF+IFN',
#   'stim_class': 4,
#   'stim_class_simple': 2,
#   'bn': '210217_EXP5_TNFIFN_tdTomOTI_1_s1c1.tif'}}

# %% [markdown]
# ### get list of all folders and all image files

# %%
folder_list = [os.path.join(ds_dir, folder_name) for folder_name in sorted(os.listdir(ds_dir)) if os.path.isdir(os.path.join(ds_dir, folder_name))]

# %%
img_names = []
folder_names = []
for folder in folder_list:
    for img in sorted(os.listdir(folder)): 
        img_name = os.path.join(folder, img)
        img_names.append(img_name)
        folder_names.append(folder)

# %% [markdown]
# #### build dataframe

# %%
dict_Df = pd.DataFrame.from_dict(info, orient='index') 
paths_Df = pd.DataFrame({'path_to_img': img_names, 'path_to_folder': folder_names})

# %% [markdown]
# add image id (3 digits of folder + 3 digits of image)

# %%
paths_Df['img_id'] = paths_Df.apply(lambda row: re.search(r'/(\d{3})/(\d{3})', row.path_to_img).group(1) + re.search(r'/(\d{3})/(\d{3})', row.path_to_img).group(2), axis=1)

# %% [markdown]
# - add group to ``paths_Df``
# - add info of ``dict_Df`` to ``paths_Df`` by merging using group

# %%
paths_Df['group'] = paths_Df.apply(lambda row: int(re.search(r'/(\d{3})$', row.path_to_folder).group(1)), axis=1)

# %%
dict_Df['group'] = dict_Df.index

# %%
df = pd.merge(paths_Df, dict_Df, on='group')

# %% [markdown]
# for each group:
#
# - shuffle indices
# - last 20% for test data
# - remaining 80% for train data

# %% [markdown]
# create lists of indices for test and train

# %%
test_indices = []
train_indices = []

groups = df['group'].unique()

for group in groups: 
    df_temp = df[df['group'] == group]
    idxs = df_temp.index
    idxs = np.random.RandomState(seed=18).permutation(idxs) 
    n_test_data = int(len(idxs) * 0.2) 
    if n_test_data >= 1:
        test_indices.append(idxs[-n_test_data:])
        train_indices.append(idxs[:-n_test_data])
    else: 
        test_indices.append(idxs[-1:])
        train_indices.append(idxs[:-1])
        
test_indices = np.concatenate( test_indices, axis=0 )
train_indices = np.concatenate( train_indices, axis=0 )

# %%
test_indices
# Out:
# array([  2,  10,  18,  26,  34,  42,  50,  54,  58,  62,  70,  78,  86,
#         94, 102, 110, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190,
#        198, 204, 210])

# %% [markdown]
# create train and test dataframe with indices

# %%
test_df = df.loc[test_indices]
train_df = df.loc[train_indices]

# %%
test_df
# Out:
#                                            path_to_img  \
# 2    /Users/saskia/unibe19/master_thesis/TKI_projec...
# 10   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 18   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 26   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 34   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 42   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 50   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 54   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 58   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 62   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 70   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 78   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 86   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 94   /Users/saskia/unibe19/master_thesis/TKI_projec...
# 102  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 110  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 118  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 126  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 134  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 142  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 150  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 158  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 166  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 174  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 182  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 190  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 198  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 204  /Users/saskia/unibe19/master_thesis/TKI_projec...
# 210  /Users/saskia/unibe19/master_thesis/TKI_projec...
#
#                                         path_to_folder  img_id  group exp  \
# 2    /Users/saskia/unibe19/master_thesis/TKI_projec...  000002      0  LM
# 10   /Users/saskia/unibe19/master_thesis/TKI_projec...  001002      1  LM
# 18   /Users/saskia/unibe19/master_thesis/TKI_projec...  002002      2  LM
# 26   /Users/saskia/unibe19/master_thesis/TKI_projec...  003002      3  LM
# 34   /Users/saskia/unibe19/master_thesis/TKI_projec...  004002      4  LM
# 42   /Users/saskia/unibe19/master_thesis/TKI_projec...  005002      5  LM
# 50   /Users/saskia/unibe19/master_thesis/TKI_projec...  006002      6  SS
# 54   /Users/saskia/unibe19/master_thesis/TKI_projec...  007002      7  SS
# 58   /Users/saskia/unibe19/master_thesis/TKI_projec...  008002      8  SS
# 62   /Users/saskia/unibe19/master_thesis/TKI_projec...  009002      9  SS
# 70   /Users/saskia/unibe19/master_thesis/TKI_projec...  010002     10  SS
# 78   /Users/saskia/unibe19/master_thesis/TKI_projec...  011002     11  SS
# 86   /Users/saskia/unibe19/master_thesis/TKI_projec...  012002     12  SS
# 94   /Users/saskia/unibe19/master_thesis/TKI_projec...  013002     13  SS
# 102  /Users/saskia/unibe19/master_thesis/TKI_projec...  014002     14  SS
# 110  /Users/saskia/unibe19/master_thesis/TKI_projec...  015002     15  SS
# 118  /Users/saskia/unibe19/master_thesis/TKI_projec...  016002     16  SS
# 126  /Users/saskia/unibe19/master_thesis/TKI_projec...  017002     17  SS
# 134  /Users/saskia/unibe19/master_thesis/TKI_projec...  018002     18  SS
# 142  /Users/saskia/unibe19/master_thesis/TKI_projec...  019002     19  SS
# 150  /Users/saskia/unibe19/master_thesis/TKI_projec...  020002     20  SS
# 158  /Users/saskia/unibe19/master_thesis/TKI_projec...  021002     21  SS
# 166  /Users/saskia/unibe19/master_thesis/TKI_projec...  022002     22  SS
# 174  /Users/saskia/unibe19/master_thesis/TKI_projec...  023002     23  SS
# 182  /Users/saskia/unibe19/master_thesis/TKI_projec...  024002     24  SA
# 190  /Users/saskia/unibe19/master_thesis/TKI_projec...  025002     25  SA
# 198  /Users/saskia/unibe19/master_thesis/TKI_projec...  026002     26  SA
# 204  /Users/saskia/unibe19/master_thesis/TKI_projec...  027002     27  SA
# 210  /Users/saskia/unibe19/master_thesis/TKI_projec...  028002     28  SA
#
#            stim  stim_class  stim_class_simple  \
# 2    IL-1b High           1                  1
# 10          TNF           3                  2
# 18   IL-1b High           1                  1
# 26           NS           0                  0
# 34           NS           0                  0
# 42   IL-1b High           1                  1
# 50    IL-1b Low           2                  1
# 54   IL-1b High           1                  1
# 58    IL-1b Low           2                  1
# 62   IL-1b High           1                  1
# 70   IL-1b High           1                  1
# 78          TNF           3                  2
# 86           NS           0                  0
# 94          TNF           3                  2
# 102  IL-1b High           1                  1
# 110         TNF           3                  2
# 118          NS           0                  0
# 126  IL-1b High           1                  1
# 134         TNF           3                  2
# 142          NS           0                  0
# 150  IL-1b High           1                  1
# 158         TNF           3                  2
# 166          NS           0                  0
# 174         TNF           3                  2
# 182     TNF+IFN           4                  2
# 190          NS           0                  0
# 198          NS           0                  0
# 204     TNF+IFN           4                  2
# 210     TNF+IFN           4                  2
#
#                                            bn
# 2                           1_il1b_1_s1c1.tif
# 10                           2_TNF_1_s1c1.tif
# 18                            3_IL1B_1_s1.tif
# 26                            4_NS_1_s1c1.tif
# 34                            5_NS_1_s1c1.tif
# 42                          6_IL1B_1_s1c1.tif
# 50                    FC2_Il1b_low_1_s1c1.tif
# 54                   FC3_Il1b_high_1_s1c1.tif
# 58                    FC4_Il1b_low_1_s1c1.tif
# 62                FC1_Il1b_1_to_13_1_s1c1.tif
# 70                 FC2_Il1b_1_to_4_1_s1c1.tif
# 78                 FC3_TNFa_1_to_8_1_s1c1.tif
# 86                   FC4_NS_1_to_8_1_s1c1.tif
# 94                 FC5_TNFa_1_to_8_1_s1c1.tif
# 102                FC6_Il1b_1_to_8_1_s1c1.tif
# 110                FC7_TNFa_1_to_8_1_s1c1.tif
# 118                  FC8_NS_1_to_8_1_s1c1.tif
# 126                FC9_Il1b_1_to_8_1_s1c1.tif
# 134               FC10_TNFa_1_to_8_1_s1c1.tif
# 142                 FC11_NS_1_to_8_1_s1c1.tif
# 150               FC12_Il1b_1_to_8_1_s1c1.tif
# 158               FC13_TNFa_1_to_8_1_s1c1.tif
# 166                 FC14_NS_1_to_8_1_s1c1.tif
# 174               FC15_TNFa_1_to_8_1_s1c1.tif
# 182  210217_EXP1_TNFIFN_tdTomOTI_1_h5s1c1.tif
# 190        210217_EXP2_NS_tdTomOTI_1_s1c1.tif
# 198        210217_EXP3_NS_tdTomOTI_1_s1c1.tif
# 204    210217_EXP4_TNFIFN_tdTomOTI_1_s1c1.tif
# 210    210217_EXP5_TNFIFN_tdTomOTI_1_s1c1.tif

# %% [markdown]
# ### creating new directories

# %%
folder = os.path.join(datadir, 'dataset5classes')
if not os.path.exists(folder):
    os.mkdir(folder)
train_folder = os.path.join(folder, 'train')
if not os.path.exists(train_folder):
    os.mkdir(train_folder)
test_folder = os.path.join(folder, 'test') 
if not os.path.exists(test_folder): 
    os.mkdir(test_folder)

# %% [markdown]
# create folder for classes:

# %%
test_folder
# Out:
# '/Users/saskia/unibe19/master_thesis/TKI_project/data/dataset5classes/test'

# %%
classes = df['stim_class'].unique()

for folder in [test_folder, train_folder]:

    for a_class in classes:
        class_folder = os.path.join(folder, str(a_class))
        if not os.path.exists(class_folder): 
            os.mkdir(class_folder)

# %% [markdown]
# assign to group_folder - *copy images*

# %%
for df, folder in zip([train_df, test_df], [train_folder, test_folder]):
    for original_path, img_id, label in zip(df['path_to_img'], df['img_id'], df['stim_class']): 
        dest_folder = os.path.join(folder, str(label), str(img_id) + '.png') # renamed with img_id 
        shutil.copy(original_path, dest_folder)
